# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonu0Sharma/Data_Visualisation-/blob/main/Practice__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hi")
# Out:
# hi

# %%
# !pip install pandas numpy matplotlib scikit-learn

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45a2a0d9-ed77-4d1a-abfc-6d8ac6050d7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45a2a0d9-ed77-4d1a-abfc-6d8ac6050d7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'Red_Wine_Quality_DataSet.csv', 'sample_data']

# %%
import pandas as pd

# Adjust the delimiter based on the actual file format
file_path = 'Red_Wine_Quality_DataSet.csv'
wine_data = pd.read_csv(file_path, delimiter=',')  # If the file uses commas

# Display the first few rows to check alignment
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Standardize the data (important for PCA)
features = wine_data.iloc[:, :-1]  # Excluding the 'quality' column
features_scaled = StandardScaler().fit_transform(features)

# %%
# Apply PCA to reduce to 3 components
pca = PCA(n_components=3)
principal_components = pca.fit_transform(features_scaled)

# %%
# Create a DataFrame for the 3D plot
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3'])
pca_df['quality'] = wine_data['quality']

# %%
# Plot the 3D PCA graph
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create scatter plot and color by wine quality
scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'],
                     c=pca_df['quality'], cmap='plasma', s=50)

# Add labels
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

# Add a color bar to indicate wine quality
fig.colorbar(scatter, ax=ax, label='Wine Quality')

plt.show()

# %%
# Plot the 3D PCA graph
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create scatter plot and color by wine quality
scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'],
                     c=pca_df['quality'], cmap='viridis', s=50)

# Add labels
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

# Add a color bar to indicate wine quality
fig.colorbar(scatter, ax=ax, label='Wine Quality')

plt.show()

# %%
# Plot the 3D PCA graph
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Create scatter plot and color by wine quality
scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'],
                     c=pca_df['quality'], cmap='inferno', s=50)

# Add labels
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

# Add a color bar to indicate wine quality
fig.colorbar(scatter, ax=ax, label='Wine Quality')

plt.show()

# %%
# Plot the 3D PCA graph with enhancements
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Create scatter plot and color by wine quality
scatter = ax.scatter(pca_df['PC1'], pca_df['PC2'], pca_df['PC3'],
                     c=pca_df['quality'], cmap='viridis', s=60, alpha=0.7)

# Add labels
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')

# Add a color bar to indicate wine quality
colorbar = fig.colorbar(scatter, ax=ax, label='Wine Quality')

# Add a title
ax.set_title('3D PCA of Red Wine Quality Dataset')

plt.show()

# %%
# !pip install plotly

# %%
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Load the red wine dataset
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
wine_data = pd.read_csv(url, delimiter=';')

# Standardize the data
features = wine_data.iloc[:, :-1]  # Excluding the 'quality' column
features_scaled = StandardScaler().fit_transform(features)

# Apply PCA to reduce to 3 components
pca = PCA(n_components=3)
principal_components = pca.fit_transform(features_scaled)

# Create a DataFrame for the plot
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2', 'PC3'])
pca_df['quality'] = wine_data['quality']

# Create interactive 3D scatter plot with Plotly
fig = px.scatter_3d(pca_df, x='PC1', y='PC2', z='PC3',
                    color='quality',
                    labels={'PC1': 'Principal Component 1',
                            'PC2': 'Principal Component 2',
                            'PC3': 'Principal Component 3',
                            'quality': 'Wine Quality'},
                    title='3D PCA of Red Wine Quality Dataset')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 3d Moving model Created
